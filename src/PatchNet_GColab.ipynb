# %% [markdown]
# # **PatchNet**

# %% [markdown]
# ## 1. Prepare code & Data

# %% [markdown]
# ### Mount Google Drive and make a directory

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Download and unzip data

# %%
# https://stackoverflow.com/questions/59120853/google-colab-is-so-slow-while-reading-images-from-google-drive
!7z x '/content/gdrive/MyDrive/datasets/pnData.zip' #-d '/content'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3976388571 bytes (3793 MiB)
#
# Extracting archive: /content/gdrive/MyDrive/datasets/pnData.zip
# --
# Path = /content/gdrive/MyDrive/datasets/pnData.zip
# Type = zip
# Physical Size = 3976388571
# 64-bit = +
#
# Everything is Ok
#
# Folders: 8
# Files: 79335
# Size:       4042222126
# Compressed: 3976388571

# %% [markdown]
# ### Clone repo from github and pull from the PatchNet branch

# %%
username = 'Atamarado'
repository = 'DLVR_3DReconstruction'
git_token = "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"#INSERT ACCESS TOKEN HERE#

# !git clone -b PatchNet https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'DLVR_3DReconstruction'...
# remote: Enumerating objects: 558, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 558 (delta 161), reused 164 (delta 76), pack-reused 308
# Receiving objects: 100% (558/558), 6.06 MiB | 3.96 MiB/s, done.
# Resolving deltas: 100% (279/279), done.

# %% [markdown]
# ## 2. Training

# %% [markdown]
# ### Imports

# %%
# %cd 'DLVR_3DReconstruction/src'
from patch.PatchNet_tf import PatchNet
from DataGenerator import DataGenerator
from Feed_data import train, test
# %cd ..
# %cd ..
# Out:
# /content/DLVR_3DReconstruction/src
# /content/DLVR_3DReconstruction
# /content

# %% [markdown]
# ### Settings

# %%
epochs = 10
patch_size = 128
min_channels = 8
batch_size = 32
train_path = "pnData/train"

# %% [markdown]
# ### Network & DataGenerator

# %%
# train process happens as follows
patchnet = PatchNet(patch_size, min_channels)
datagen = DataGenerator(train_path, batch_size, patching = True, patch_size = patch_size)

# %% [markdown]
# ### Training

# %%
# use train to train patchnet
train(patchnet, datagen, epochs, n_train_batches = 80, n_val_batches = 20)
# Out:
# Training progress:  18%|█▊        | 14/80 [00:24<01:56,  1.77s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5568ec3ab322> in <module>
#       1 # use train to train patchnet
# ----> 2 train(patchnet, datagen, epochs, n_train_batches = 80, n_val_batches = 20)
#
# /content/DLVR_3DReconstruction/src/Feed_data.py in train(model, data_generator, epochs, n_batches, n_train_batches, n_val_batches)
#      73
#      74     for epoch in range(epochs):
# ---> 75         train_loss = patch_loop(model, data_generator, validation = False, n_batches = n_train_batches)
#      76         val_loss_patch = patch_loop(model, data_generator, validation = True, n_batches = n_val_batches)
#      77         val_loss_img = image_loop(model, data_generator, n_batches = n_val_batches)
#
# /content/DLVR_3DReconstruction/src/Feed_data.py in patch_loop(model, data_generator, validation, n_batches)
#      25     # loop over the data
#      26     for i in tqdm(range(n_batches), desc = desc): # TO-DO: replace 10 with n_batches for final training loop
# ---> 27         inputs, maps = data_generator.__getitem__(i)
#      28         patches = inputs[:,:,:,0:3]
#      29         foreground_map = tf.reshape(inputs[:,:,:,3], inputs.shape[:-1] + tuple([1]))
#
# /content/DLVR_3DReconstruction/src/DataGenerator.py in __getitem__(self, index)
#     147         batches = self.objs[start_index:end_index]
#     148
# --> 149         X, y = self.__get_data__(batches)
#     150         return X, y
#     151
#
# /content/DLVR_3DReconstruction/src/DataGenerator.py in __get_data__(self, batches)
#     108             for i in range(len(batches)):
#     109                 X_patched_i, _, _ = tensor_patching(X_batch[i], self.patch_size)
# --> 110                 y_patched_i, _, _ = tensor_patching(y_batch[i], self.patch_size)
#     111                 X_patched = tf.concat((X_patched, tf.cast(X_patched_i, dtype = "float32")), axis = 0)
#     112                 y_patched = tf.concat((y_patched, tf.cast(y_patched_i, dtype = "float32")), axis = 0)
#
# /content/DLVR_3DReconstruction/src/patch/Patching.py in tensor_patching(img, patch_size, return_intervals)
#      99
#     100 def tensor_patching(img, patch_size, return_intervals = True):
# --> 101     patches, height_info, width_info = patching(img, patch_size, return_intervals)
#     102     return patches_to_tensor(patches, patch_size), height_info, width_info
#     103
#
# /content/DLVR_3DReconstruction/src/patch/Patching.py in patching(img, patch_size, return_intervals)
#      78
#      79     for i in range(channels):
# ---> 80         patches[i], height_intervals, width_intervals = patch_matrix(img[:,:,i], patch_size, n_height, n_width)
#      81
#      82     if return_intervals:
#
# /content/DLVR_3DReconstruction/src/patch/Patching.py in patch_matrix(img_matrix, patch_size, n_height, n_width)
#      48         width_cut_end = width_cut_start + patch_size
#      49         index = (n_height - 1) * n_width + w
# ---> 50         patches[index] = img_matrix[-patch_size:, width_cut_start:width_cut_end]
#      51         # save the intervals of the pixels (necessary for stitching later)
#      52         height_intervals[index] = np.array([height - patch_size, height])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#    1106         ellipsis_mask=ellipsis_mask,
#    1107         var=var,
# -> 1108         name=name)
#    1109
#    1110
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1278       ellipsis_mask=ellipsis_mask,
#    1279       new_axis_mask=new_axis_mask,
# -> 1280       shrink_axis_mask=shrink_axis_mask)
#    1281
#    1282   parent_name = name
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10666         _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10667         begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
# > 10668         "new_axis_mask", new_axis_mask, "shrink_axis_mask", shrink_axis_mask)
#   10669       return _result
#   10670     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ##3. Testing

# %% [markdown]
# ### Test settings

# %%
# test with test data
test_path = "pnData/test"

# %% [markdown]
# ### Test DataGenerator

# %%
datagen_test = DataGenerator(test_path, batch_size, patching = False, train_val_split = 1.0)

# %% [markdown]
# ### Testing

# %%
test(patchnet, datagen_test, n_batches = 2)
